# %% [markdown]
# <a href="https://colab.research.google.com/github/jawnaw2000/Working-with-Semiprimes/blob/main/Working_with_Semiprimes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
